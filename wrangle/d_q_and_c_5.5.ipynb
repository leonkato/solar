# %% [markdown]
# ### Part 5.5 of data cleaning
#
# #### Agenda
#
# * 20180109 Okay up to here.  Now work through this again
# * re-index so I can get at the data to drop
# * Get rid of 29925 rows with no installation type.  They are not helpful since my project is focused on residential installations.  I might be able to statistically infer which ones are residential, but that would be a different kind of project.
#
# * Get rid of duplicate data.  What does that mean exactly?
#
#     1. strict duplicates - two or more more rows where every column of each contains exactly the same data
#     2. strict duplicates with relaxed floating point comparisons ($r_1(var_n) - r_2(var_n) < epsilon$ for some small epsilon)
#     3. subset duplicates - these are rows that have the most significant fields equal and differences or missing data in the other fields.  My theory on this is that they come from multiple loads of similar datasets (perhaps from different sources).
#     4. subset duplicates with relaxed floating point comparisons
#     5. other - typos, wrong dates, bad math
#
# The dataset loaded by this code contains ~745k rows.  The changes leading to the initial reduction are summarized in the table below:
#
# file                  | beginning rows    | end rows  |output file         | comments
# ----------------------|-------------------|-----------|-----------------------------------------------------------------
# d_q_and_c_1           | 1020524           | 1020516   |                    | delete rows with null indices (drop 8 rows)
# d_q_and_c_2           | 1020516           | 1020516   |                    | no changes
# d_q_and_c_3           | 1020516           | 1002025   | live20171229.csv   | save data from 2004-2015 inclusive (drop 18491 rows)
# d_q_and_c_install_type| 1002025           | 1002025   | 20180101.csv       | clean install_type; no change in rows
# d_q_and_c_5           | 1002025           |  745362   | 20180105           | drop rows without all of size_kw, cost, cost_per_watt (~250k)
# d_q_and_c_5.5         |  745362           | 61614     | 20180109.csv       | dropped many duplicate entries

# %%
# %load ../pycode/setup.py
# set up
import numpy as np
import pandas as pd
import random
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %matplotlib inline

def ecdf(data):
    '''Compute ECDF for a one-dimensional array of measurements.'''
    n = len(data)
    x = np.sort(data)
    y = np.arange(1, n + 1) / n
    return x, y

def min015099max(series, minmax=False):
    ''' return list of [ min, 1%, median, 99%, max ] series values '''
    vals = list(np.percentile(series, [1.0, 50.0, 99.0]))
    if minmax: 
        vals.insert(0, series.min())
        vals.append(series.max())    
    return vals
# ss = np.arange(1, 101)
# min_1_50_99_max(ss)             

def mid98(series):
    '''  return middle 98% of series '''
    bounds = series.quantile([0.01, 0.99])
    return(series[(series > bounds.values[0]) & (series < bounds.values[1])])

# ss = np.arange(1, 101)
# min_1_50_99_max(ss)

# %%
# load dataset
dfLive = pd.read_csv('../local/data/20180105', index_col='date_installed', 
                     parse_dates=True, dtype={'zipcode' : np.object})

# %%
# how big? 745k.  how many nulls?
dfLive.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 745362 entries, 2004-01-01 to 2015-12-31
# Data columns (total 19 columns):
# Unnamed: 0       745362 non-null int64
# cost_per_watt    745362 non-null float64
# cost             745362 non-null float64
# size_kw          745362 non-null float64
# state            745362 non-null object
# zipcode          745362 non-null object
# city             552240 non-null object
# county           732641 non-null object
# new_constr       23813 non-null float64
# tracking         1705 non-null float64
# third_party      239541 non-null float64
# appraised        146655 non-null object
# incentive        552618 non-null object
# utility          550246 non-null object
# tech             421871 non-null object
# model            421871 non-null object
# installer        470553 non-null object
# bipv             3897 non-null float64
# i_type           715437 non-null object
# dtypes: float64(7), int64(1), object(11)
# memory usage: 113.7+ MB

# %%
# drop column that's about to be redundant
dfLive.drop('Unnamed: 0', axis='columns', inplace=True)

# %%
# see what we've got 
dfLive.head()
# Out:
#                 cost_per_watt       cost  size_kw state zipcode        city  \
# date_installed
# 2004-01-01           6.150000    4000.00    0.650    TN   37397         NaN
# 2004-01-01           5.740000  195000.00   34.000    MN   55407         NaN
# 2004-01-01           7.388700   21944.44    2.970    CA   95616       Davis
# 2004-01-01          10.227273   27000.00    2.640    CA   92504   Riverside
# 2004-01-01           7.187847   32410.00    4.509    CA   94707  Kensington
#
#                    county  new_constr  tracking  third_party appraised  \
# date_installed
# 2004-01-01         Marion         NaN       NaN          NaN       NaN
# 2004-01-01       Hennepin         NaN       NaN          NaN       NaN
# 2004-01-01           Yolo         NaN       NaN          NaN       NaN
# 2004-01-01      Riverside         NaN       NaN          NaN       NaN
# 2004-01-01        Alameda         NaN       NaN          NaN       NaN
#
#                                                         incentive  \
# date_installed
# 2004-01-01                                                    NaN
# 2004-01-01                                                    NaN
# 2004-01-01      California Energy Commission (Emerging Renewab...
# 2004-01-01      California Energy Commission (Emerging Renewab...
# 2004-01-01      California Energy Commission (Emerging Renewab...
#
#                                        utility  tech     model  \
# date_installed
# 2004-01-01                                 NaN   NaN       NaN
# 2004-01-01                                 NaN   NaN       NaN
# 2004-01-01      Pacific Gas & Electric Company   NaN       NaN
# 2004-01-01          Southern California Edison   NaN       NaN
# 2004-01-01      Pacific Gas & Electric Company  Poly  ND-167U1
#
#                                  installer  bipv      i_type
# date_installed
# 2004-01-01                             NaN   NaN         NaN
# 2004-01-01                             NaN   NaN  commercial
# 2004-01-01      Davis Lumber & Hardware Co   NaN         NaN
# 2004-01-01            Future Air & Windows   NaN         NaN
# 2004-01-01              Wencon Development   NaN         NaN

# %%
# index by row_id
dfLive.reset_index(inplace=True)

# %%
# look at index and columns
dfLive.head()
# Out:
#   date_installed  cost_per_watt       cost  size_kw state zipcode        city  \
# 0     2004-01-01       6.150000    4000.00    0.650    TN   37397         NaN
# 1     2004-01-01       5.740000  195000.00   34.000    MN   55407         NaN
# 2     2004-01-01       7.388700   21944.44    2.970    CA   95616       Davis
# 3     2004-01-01      10.227273   27000.00    2.640    CA   92504   Riverside
# 4     2004-01-01       7.187847   32410.00    4.509    CA   94707  Kensington
#
#       county  new_constr  tracking  third_party appraised  \
# 0     Marion         NaN       NaN          NaN       NaN
# 1   Hennepin         NaN       NaN          NaN       NaN
# 2       Yolo         NaN       NaN          NaN       NaN
# 3  Riverside         NaN       NaN          NaN       NaN
# 4    Alameda         NaN       NaN          NaN       NaN
#
#                                            incentive  \
# 0                                                NaN
# 1                                                NaN
# 2  California Energy Commission (Emerging Renewab...
# 3  California Energy Commission (Emerging Renewab...
# 4  California Energy Commission (Emerging Renewab...
#
#                           utility  tech     model                   installer  \
# 0                             NaN   NaN       NaN                         NaN
# 1                             NaN   NaN       NaN                         NaN
# 2  Pacific Gas & Electric Company   NaN       NaN  Davis Lumber & Hardware Co
# 3      Southern California Edison   NaN       NaN        Future Air & Windows
# 4  Pacific Gas & Electric Company  Poly  ND-167U1          Wencon Development
#
#    bipv      i_type
# 0   NaN         NaN
# 1   NaN  commercial
# 2   NaN         NaN
# 3   NaN         NaN
# 4   NaN         NaN

# %%
# rename the index for clarity
dfLive.rename_axis('row_id', inplace=True)

# %%
dfLive.head()
# Out:
#        date_installed  cost_per_watt       cost  size_kw state zipcode  \
# row_id
# 0          2004-01-01       6.150000    4000.00    0.650    TN   37397
# 1          2004-01-01       5.740000  195000.00   34.000    MN   55407
# 2          2004-01-01       7.388700   21944.44    2.970    CA   95616
# 3          2004-01-01      10.227273   27000.00    2.640    CA   92504
# 4          2004-01-01       7.187847   32410.00    4.509    CA   94707
#
#               city     county  new_constr  tracking  third_party appraised  \
# row_id
# 0              NaN     Marion         NaN       NaN          NaN       NaN
# 1              NaN   Hennepin         NaN       NaN          NaN       NaN
# 2            Davis       Yolo         NaN       NaN          NaN       NaN
# 3        Riverside  Riverside         NaN       NaN          NaN       NaN
# 4       Kensington    Alameda         NaN       NaN          NaN       NaN
#
#                                                 incentive  \
# row_id
# 0                                                     NaN
# 1                                                     NaN
# 2       California Energy Commission (Emerging Renewab...
# 3       California Energy Commission (Emerging Renewab...
# 4       California Energy Commission (Emerging Renewab...
#
#                                utility  tech     model  \
# row_id
# 0                                  NaN   NaN       NaN
# 1                                  NaN   NaN       NaN
# 2       Pacific Gas & Electric Company   NaN       NaN
# 3           Southern California Edison   NaN       NaN
# 4       Pacific Gas & Electric Company  Poly  ND-167U1
#
#                          installer  bipv      i_type
# row_id
# 0                              NaN   NaN         NaN
# 1                              NaN   NaN  commercial
# 2       Davis Lumber & Hardware Co   NaN         NaN
# 3             Future Air & Windows   NaN         NaN
# 4               Wencon Development   NaN         NaN

# %% [markdown]
# #### Reindexing is done.  Now take care of rows with null i_type.

# %%
# how many?
dfLive.i_type.isnull().sum()
# Out:
# 29925

# %%
# drop them
dfLive.drop(dfLive[dfLive.i_type.isnull()].index, inplace=True)

# %%
# all gone
dfLive.i_type.isnull().sum()
# Out:
# 0

# %%
# down to 715k
dfLive.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 715437 entries, 1 to 745361
# Data columns (total 19 columns):
# date_installed    715437 non-null datetime64[ns]
# cost_per_watt     715437 non-null float64
# cost              715437 non-null float64
# size_kw           715437 non-null float64
# state             715437 non-null object
# zipcode           715437 non-null object
# city              526210 non-null object
# county            702938 non-null object
# new_constr        21238 non-null float64
# tracking          1635 non-null float64
# third_party       239336 non-null float64
# appraised         146051 non-null object
# incentive         525525 non-null object
# utility           523209 non-null object
# tech              408436 non-null object
# model             408436 non-null object
# installer         457974 non-null object
# bipv              3126 non-null float64
# i_type            715437 non-null object
# dtypes: datetime64[ns](1), float64(7), object(11)
# memory usage: 109.2+ MB

# %% [markdown]
# ####  Having dropped all rows with null i_type we have 715437 rows left.

# %% [markdown]
# #### Now on to duplicates.
#
# There are several kinds of duplicates.  Exact dups have all fields exactly the same.

# %%
# every field exactly the same as another row?
completeDups = dfLive.duplicated(keep=False)

# %%
# how many? 34k
len(dfLive[completeDups])
# Out:
# 34124

# %%
# have a look at some of them
# everything is the same in these. I've got 2, 3, and 4 dups just in this little sample
dfLive[completeDups].head(15)
# Out:
#        date_installed  cost_per_watt       cost  size_kw state zipcode  \
# row_id
# 282        2004-01-13          10.00   50000.00     5.00    NY   11788
# 283        2004-01-13          10.00   50000.00     5.00    NY   11788
# 681        2004-01-26           9.26   26656.00     2.88    CA   95627
# 701        2004-01-26           9.26   26656.00     2.88    CA   95627
# 805        2004-02-01          13.81  319000.00    23.10    CT   06141
# 806        2004-02-01          13.81  319000.00    23.10    CT   06141
# 894        2004-02-04           6.08   19454.00     3.20    CA   94303
# 899        2004-02-04           6.08   19454.00     3.20    CA   94303
# 901        2004-02-04           6.08   19454.00     3.20    CA   94303
# 917        2004-02-04           6.08   19454.00     3.20    CA   94303
# 1227       2004-02-20           6.55   14679.34     2.24    CA   95616
# 1257       2004-02-20           6.55   14679.34     2.24    CA   95616
# 1501       2004-02-26           9.21   11054.38     1.20    CA   92109
# 1507       2004-02-26           9.21   11054.38     1.20    CA   92109
# 1516       2004-02-26           9.21   11054.38     1.20    CA   92109
#
#              city       county  new_constr  tracking  third_party appraised  \
# row_id
# 282     Hauppauge      Suffolk         NaN       NaN          NaN       NaN
# 283     Hauppauge      Suffolk         NaN       NaN          NaN       NaN
# 681           NaN         Yolo         NaN       NaN          NaN       NaN
# 701           NaN         Yolo         NaN       NaN          NaN       NaN
# 805           NaN          NaN         NaN       NaN          NaN       NaN
# 806           NaN          NaN         NaN       NaN          NaN       NaN
# 894           NaN  Santa Clara         NaN       NaN          NaN       NaN
# 899           NaN  Santa Clara         NaN       NaN          NaN       NaN
# 901           NaN  Santa Clara         NaN       NaN          NaN       NaN
# 917           NaN  Santa Clara         NaN       NaN          NaN       NaN
# 1227          NaN         Yolo         NaN       NaN          NaN       NaN
# 1257          NaN         Yolo         NaN       NaN          NaN       NaN
# 1501          NaN    San Diego         NaN       NaN          NaN       NaN
# 1507          NaN    San Diego         NaN       NaN          NaN       NaN
# 1516          NaN    San Diego         NaN       NaN          NaN       NaN
#
#                                                 incentive           utility  \
# row_id
# 282     New York State Energy Research and Development...  PSEG Long Island
# 283     New York State Energy Research and Development...  PSEG Long Island
# 681                                                   NaN               NaN
# 701                                                   NaN               NaN
# 805                                                   NaN               NaN
# 806                                                   NaN               NaN
# 894                                                   NaN               NaN
# 899                                                   NaN               NaN
# 901                                                   NaN               NaN
# 917                                                   NaN               NaN
# 1227                                                  NaN               NaN
# 1257                                                  NaN               NaN
# 1501                                                  NaN               NaN
# 1507                                                  NaN               NaN
# 1516                                                  NaN               NaN
#
#        tech model installer  bipv       i_type
# row_id
# 282     NaN   NaN       NaN   NaN  residential
# 283     NaN   NaN       NaN   NaN  residential
# 681     NaN   NaN       NaN   NaN  residential
# 701     NaN   NaN       NaN   NaN  residential
# 805     NaN   NaN       NaN   NaN      unknown
# 806     NaN   NaN       NaN   NaN      unknown
# 894     NaN   NaN       NaN   NaN  residential
# 899     NaN   NaN       NaN   NaN  residential
# 901     NaN   NaN       NaN   NaN  residential
# 917     NaN   NaN       NaN   NaN  residential
# 1227    NaN   NaN       NaN   NaN  residential
# 1257    NaN   NaN       NaN   NaN  residential
# 1501    NaN   NaN       NaN   NaN  residential
# 1507    NaN   NaN       NaN   NaN  residential
# 1516    NaN   NaN       NaN   NaN  residential

# %%
# same kind of thing here
dfLive[completeDups].tail(16)
# Out:
#        date_installed  cost_per_watt       cost     size_kw state zipcode  \
# row_id
# 744328     2015-12-31       3.000000  592920.00  197.640000    NY   12010
# 744369     2015-12-31       3.000000  592920.00  197.640000    NY   12010
# 744397     2015-12-31       4.019637  268994.14   66.920000    NY   12306
# 744401     2015-12-31       4.019637  268994.14   66.920000    NY   12306
# 744404     2015-12-31       4.019637  268994.14   66.920000    NY   12306
# 744418     2015-12-31       4.019637  268994.14   66.920000    NY   12306
# 744479     2015-12-31       4.019637  268994.14   66.920000    NY   12306
# 744521     2015-12-31       5.119934   31206.00    6.095000    CA   92154
# 744529     2015-12-31       5.119934   31206.00    6.095000    CA   92154
# 744852     2015-12-31       3.983456    5500.00    1.380711    CA   91780
# 744853     2015-12-31       3.983456    5500.00    1.380711    CA   91780
# 744854     2015-12-31       3.983456    5500.00    1.380711    CA   91780
# 744907     2015-12-31       4.500000   27000.00    6.000000    CT   06606
# 744910     2015-12-31       4.500000   27000.00    6.000000    CT   06606
# 745138     2015-12-31       4.400000   25652.00    5.830000    AZ   85614
# 745139     2015-12-31       4.400000   25652.00    5.830000    AZ   85614
#
#                 city       county  new_constr  tracking  third_party  \
# row_id
# 744328     Amsterdam   Montgomery         NaN       NaN          1.0
# 744369     Amsterdam   Montgomery         NaN       NaN          1.0
# 744397   Schenectady  Schenectady         NaN       NaN          1.0
# 744401   Schenectady  Schenectady         NaN       NaN          1.0
# 744404   Schenectady  Schenectady         NaN       NaN          1.0
# 744418   Schenectady  Schenectady         NaN       NaN          1.0
# 744479   Schenectady  Schenectady         NaN       NaN          1.0
# 744521     SAN DIEGO    San Diego         NaN       NaN          NaN
# 744529     SAN DIEGO    San Diego         NaN       NaN          NaN
# 744852   Temple City  Los Angeles         NaN       NaN          NaN
# 744853   Temple City  Los Angeles         NaN       NaN          NaN
# 744854   Temple City  Los Angeles         NaN       NaN          NaN
# 744907    Bridgeport    Fairfield         NaN       NaN          1.0
# 744910    Bridgeport    Fairfield         NaN       NaN          1.0
# 745138  GREEN VALLEY         Pima         NaN       NaN          NaN
# 745139  GREEN VALLEY         Pima         NaN       NaN          NaN
#
#        appraised                                          incentive  \
# row_id
# 744328       NaN  New York State Energy Research and Development...
# 744369       NaN  New York State Energy Research and Development...
# 744397       NaN  New York State Energy Research and Development...
# 744401       NaN  New York State Energy Research and Development...
# 744404       NaN  New York State Energy Research and Development...
# 744418       NaN  New York State Energy Research and Development...
# 744479       NaN  New York State Energy Research and Development...
# 744521      True  California Public Utilities Commission (Non-CS...
# 744529      True  California Public Utilities Commission (Non-CS...
# 744852       NaN  California Public Utilities Commission (Non-CS...
# 744853       NaN  California Public Utilities Commission (Non-CS...
# 744854       NaN  California Public Utilities Commission (Non-CS...
# 744907       NaN  Connecticut Clean Energy Finance and Investmen...
# 744910       NaN  Connecticut Clean Energy Finance and Investmen...
# 745138      True                              Tucson Electric Power
# 745139      True                              Tucson Electric Power
#
#                                  utility  tech              model  \
# row_id
# 744328                     National Grid  Poly   multiple matches
# 744369                     National Grid  Poly   multiple matches
# 744397                     National Grid  Poly   multiple matches
# 744401                     National Grid  Poly   multiple matches
# 744404                     National Grid  Poly   multiple matches
# 744418                     National Grid  Poly   multiple matches
# 744479                     National Grid  Poly   multiple matches
# 744521  San Diego Gas & Electric Company  Poly         KU265-6ZPA
# 744529  San Diego Gas & Electric Company  Poly         KU265-6ZPA
# 744852        Southern California Edison  Mono  SW 275 Mono Black
# 744853        Southern California Edison  Mono  SW 275 Mono Black
# 744854        Southern California Edison  Mono  SW 275 Mono Black
# 744907               United Illuminating  Mono   multiple matches
# 744910               United Illuminating  Mono   multiple matches
# 745138             Tucson Electric Power   NaN                NaN
# 745139             Tucson Electric Power   NaN                NaN
#
#            installer  bipv       i_type
# row_id
# 744328           NaN   NaN   commercial
# 744369           NaN   NaN   commercial
# 744397           NaN   NaN   commercial
# 744401           NaN   NaN   commercial
# 744404           NaN   NaN   commercial
# 744418           NaN   NaN   commercial
# 744479           NaN   NaN   commercial
# 744521     SolarCity   NaN  residential
# 744529     SolarCity   NaN  residential
# 744852  PetersenDean   NaN  residential
# 744853  PetersenDean   NaN  residential
# 744854  PetersenDean   NaN  residential
# 744907       Posigen   NaN  residential
# 744910       Posigen   NaN  residential
# 745138     SolarCity   NaN  residential
# 745139     SolarCity   NaN  residential

# %%
# okay, let's get rid of those extra entries
dfNoCompleteDups = dfLive.drop_duplicates()

# %%
# down to 694k
dfNoCompleteDups.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 693961 entries, 1 to 745361
# Data columns (total 19 columns):
# date_installed    693961 non-null datetime64[ns]
# cost_per_watt     693961 non-null float64
# cost              693961 non-null float64
# size_kw           693961 non-null float64
# state             693961 non-null object
# zipcode           693961 non-null object
# city              514129 non-null object
# county            685144 non-null object
# new_constr        14855 non-null float64
# tracking          1615 non-null float64
# third_party       236320 non-null float64
# appraised         143876 non-null object
# incentive         513445 non-null object
# utility           511173 non-null object
# tech              398154 non-null object
# model             398154 non-null object
# installer         447607 non-null object
# bipv              2425 non-null float64
# i_type            693961 non-null object
# dtypes: datetime64[ns](1), float64(7), object(11)
# memory usage: 105.9+ MB

# %%
# any more? nope
dfNoCompleteDups.duplicated().sum()
# Out:
# 0

# %%
dfLive = dfNoCompleteDups

# %% [markdown]
# #### Having dropped all exact duplicates, we have 693,961 rows.

# %%
dfLive.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 693961 entries, 1 to 745361
# Data columns (total 19 columns):
# date_installed    693961 non-null datetime64[ns]
# cost_per_watt     693961 non-null float64
# cost              693961 non-null float64
# size_kw           693961 non-null float64
# state             693961 non-null object
# zipcode           693961 non-null object
# city              514129 non-null object
# county            685144 non-null object
# new_constr        14855 non-null float64
# tracking          1615 non-null float64
# third_party       236320 non-null float64
# appraised         143876 non-null object
# incentive         513445 non-null object
# utility           511173 non-null object
# tech              398154 non-null object
# model             398154 non-null object
# installer         447607 non-null object
# bipv              2425 non-null float64
# i_type            693961 non-null object
# dtypes: datetime64[ns](1), float64(7), object(11)
# memory usage: 105.9+ MB

# %% [markdown]
# ##### Now for the more insidious kind of dup.  all of the important fields are the same but there are differences in the other fields.
#
# These columns are the most important: ['date_installed', 'cost_per_watt', 'cost', 'size_kw', 'state', 'county'. 'zipcode'].  I'm $*not*$ going to use cost_per_watt because I know already that there are some of these with minor differences in rightmost decimal places. One theory come from the data being entered (or calculated from cost and size_kw) at different time with different precision.

# %%
# partially duplicated rows
pdups = dfLive.duplicated(subset=['date_installed', 'cost', 'size_kw', 'state', 'county', 'zipcode'], keep=False)

# %%
# how many?  154k.  That's a lot of rows
pdups.sum()
# Out:
# 154277

# %% [markdown]
# ##### Let's take a look at some of these.
#
# Having looked at these, I'm convinced that almost all if not every row represents the same installation as another row.
# Pairs seem to differ mostly in the 'city' column and also differ in the number of columns with missing data.
#
# Some also differ only in the columns [incentive, utility, tech, model,installer, bipv].
#
# To move ahead, we keep the first entry and delete the rest.  The downside is that we may actually lose distinct installations but, it's likely that will be quite a small percentage.  In addition, we may be losing some descriptive data fields in some entries.  If there were a way to chose between duplicates, I would specify keeping the row with less missing data.  These fields are secondary to the purpose of this project.

# %%
sortedPdups = dfLive[pdups].sort_values(['date_installed', 'state', 'zipcode', 'county'])
sortedPdups.head(12)
# Out:
#        date_installed  cost_per_watt      cost  size_kw state zipcode  \
# row_id
# 19         2004-01-05       6.620000   18278.0     2.76    MA   02451
# 21         2004-01-05       6.622464   18278.0     2.76    MA   02451
# 20         2004-01-05       6.000000   34000.0     5.67    MA   02770
# 22         2004-01-05       5.996473   34000.0     5.67    MA   02770
# 32         2004-01-07       6.700000   16953.0     2.53    MA   02474
# 46         2004-01-07       6.700791   16953.0     2.53    MA   02474
# 49         2004-01-07       9.360000  117980.0    12.60    NJ   07934
# 74         2004-01-07       9.363492  117980.0    12.60    NJ   07934
# 78         2004-01-08      12.800000   43000.0     3.36    CA   90005
# 120        2004-01-08      12.797619   43000.0     3.36    CA   90005
# 205        2004-01-09      19.460000  210160.0    10.80    MA   01915
# 217        2004-01-09      19.459259  210160.0    10.80    MA   01915
#
#                city       county  new_constr  tracking  third_party appraised  \
# row_id
# 19              NaN    Middlesex         NaN       NaN          NaN       NaN
# 21          Waltham    Middlesex         NaN       NaN          NaN       NaN
# 20              NaN     Plymouth         NaN       NaN          NaN       NaN
# 22        Rochester     Plymouth         NaN       NaN          NaN       NaN
# 32              NaN    Middlesex         NaN       NaN          NaN       NaN
# 46        Arlington    Middlesex         NaN       NaN          NaN       NaN
# 49              NaN     Somerset         NaN       NaN          NaN       NaN
# 74        GLADSTONE     Somerset         NaN       NaN          NaN       NaN
# 78              NaN  Los Angeles         NaN       NaN          NaN       NaN
# 120     Los Angeles  Los Angeles         NaN       NaN          NaN       NaN
# 205             NaN        Essex         NaN       NaN          NaN       NaN
# 217         Beverly        Essex         NaN       NaN          NaN       NaN
#
#                                                 incentive  \
# row_id
# 19                                                    NaN
# 21                      Massachusetts Clean Energy Center
# 20                                                    NaN
# 22                      Massachusetts Clean Energy Center
# 32                                                    NaN
# 46                      Massachusetts Clean Energy Center
# 49                                                    NaN
# 74      New Jersey Board of Public Utilities (CORE & R...
# 78                                                    NaN
# 120               Los Angeles Department of Water & Power
# 205                                                   NaN
# 217                     Massachusetts Clean Energy Center
#
#                                         utility tech model  \
# row_id
# 19                                          NaN  NaN   NaN
# 21                       NSTAR (DBA EverSource)  NaN   NaN
# 20                                          NaN  NaN   NaN
# 22                       NSTAR (DBA EverSource)  NaN   NaN
# 32                                          NaN  NaN   NaN
# 46                       NSTAR (DBA EverSource)  NaN   NaN
# 49                                          NaN  NaN   NaN
# 74                                        JCP&L  NaN   NaN
# 78                                          NaN  NaN   NaN
# 120     Los Angeles Department of Water & Power  NaN   NaN
# 205                                         NaN  NaN   NaN
# 217                               National Grid  NaN   NaN
#
#                                 installer  bipv       i_type
# row_id
# 19                                    NaN   NaN  residential
# 21      Conservation Services Group (Csg)   NaN  residential
# 20                                    NaN   NaN  residential
# 22               Alternate Energy Systems   NaN  residential
# 32                                    NaN   NaN  residential
# 46      Conservation Services Group (Csg)   NaN  residential
# 49                                    NaN   NaN  educational
# 74                   Solar Energy Systems   NaN  educational
# 78                                    NaN   NaN  residential
# 120                                   NaN   NaN  residential
# 205                                   NaN   NaN  educational
# 217                                 Escoa   NaN  educational

# %%
sortedPdups.city.isnull().sum()
# Out:
# 57584

# %%
sortedPdups.city.notnull().sum()
# Out:
# 96693

# %%
blee = sortedPdups[sortedPdups.city.notnull()]

# %%
bleeblop = blee[blee.duplicated(subset=['date_installed', 'cost', 'size_kw', 'state', 'county', 'zipcode'], keep=False)]

# %%
bleeblop.head()
# Out:
#        date_installed  cost_per_watt     cost  size_kw state zipcode  \
# row_id
# 4618       2004-05-20       9.174286  19266.0     2.10    NJ   08401
# 4619       2004-05-20       9.174286  19266.0     2.10    NJ   08401
# 6295       2004-07-26       7.950000  75127.5     9.45    NJ   08820
# 6318       2004-07-26       7.950000  75127.5     9.45    NJ   08820
# 14875      2005-06-08      11.232071  44479.0     3.96    MN   55051
#
#                  city     county  new_constr  tracking  third_party appraised  \
# row_id
# 4618    ATLANTIC CITY   Atlantic         NaN       NaN          NaN       NaN
# 4619    ATLANTIC CITY   Atlantic         NaN       NaN          NaN       NaN
# 6295           EDISON  Middlesex         NaN       NaN          NaN       NaN
# 6318           EDISON  Middlesex         NaN       NaN          NaN       NaN
# 14875            Mora    Kanabec         NaN       1.0          NaN       NaN
#
#                                                 incentive  \
# row_id
# 4618    New Jersey Board of Public Utilities (CORE & R...
# 4619    New Jersey Board of Public Utilities (CORE & R...
# 6295    New Jersey Board of Public Utilities (CORE & R...
# 6318    New Jersey Board of Public Utilities (CORE & R...
# 14875                    Minnesota Department of Commerce
#
#                           utility  tech             model           installer  \
# row_id
# 4618    Atlantic City Electric Co   NaN               NaN  Ecological Systems
# 4619                     Conectiv   NaN               NaN  Ecological Systems
# 6295                    PSE&G BPU  Mono  multiple matches      Sunlit Systems
# 6318                    PSE&G BPU  Mono          NT-175U1      Sunlit Systems
# 14875              Mora Municipal   NaN               NaN                 NaN
#
#         bipv       i_type
# row_id
# 4618     NaN   commercial
# 4619     NaN   commercial
# 6295     NaN    nonprofit
# 6318     NaN    nonprofit
# 14875    NaN  residential

# %%
# For my own edification, I'll save these to a csv file.
# Each row should have exactly the same values for ['date_installed', 'cost', 'size_kw', 'state', 'county', 'zipcode'] as
# another row.  Since they're sorted, the "dups" adjacent (at least, very close) in the file.
sortedPdups.to_csv('./partial_dups.csv')

# %%
dfLive.drop_duplicates(subset=['date_installed', 'cost', 'size_kw', 'state', 'county', 'zipcode'], 
                       keep='first', inplace= True)

# %%
# down to 616k
dfLive.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 616144 entries, 1 to 745361
# Data columns (total 19 columns):
# date_installed    616144 non-null datetime64[ns]
# cost_per_watt     616144 non-null float64
# cost              616144 non-null float64
# size_kw           616144 non-null float64
# state             616144 non-null object
# zipcode           616144 non-null object
# city              465435 non-null object
# county            607416 non-null object
# new_constr        13314 non-null float64
# tracking          1445 non-null float64
# third_party       211824 non-null float64
# appraised         125678 non-null object
# incentive         464753 non-null object
# utility           462605 non-null object
# tech              368886 non-null object
# model             368886 non-null object
# installer         404024 non-null object
# bipv              2010 non-null float64
# i_type            616144 non-null object
# dtypes: datetime64[ns](1), float64(7), object(11)
# memory usage: 94.0+ MB

# %%
# double check
dfLive.duplicated(subset=['date_installed', 'cost', 'size_kw', 'state', 'county', 'zipcode'], keep=False).sum()
# Out:
# 0

# %% [markdown]
# #### Having dropped a set of partial duplicates we are now at 616144 rows

# %%
dfLive.to_csv('../local/data/20180109.csv')

# %% [markdown]
# ### Stopping here.  Cells below merged and commented out because I don't trust that code to be doing what I want.  More tomorrow.

# %% [markdown]
# #### Are there still dups with only minor differences in cost/size_kw??

# %%
# # apparently there are.  THIS IS BROKEN!!!  Well actually not.  The comment is broken.
# # this line returns a boolean series that can be used to index dfLive return items where the subset is duplicated.
# # that doesn't mean minor differences in cost, could be any difference in cost.

# # hmmm, on second thought if the size is the same, should the cost be the same (if it's actually a dup)?
# # maybe not.  imagine two guys across the street.  One pays x, the other pays y.  They are flagged as a duplicate pair


# dfLive.duplicated(subset=['date_installed', 'size_kw', 'state', 'county', 'zipcode'], keep=False).sum()

# # grab them
# thing = dfLive[dfLive.duplicated(subset=['date_installed', 'size_kw', 'state', 'county', 'zipcode'], keep=False)]

# # have a look.  are they really dups??  I don't think they are
# thing.head(20)

# thingSorted = thing.sort_values(by=['date_installed', 'state', 'size_kw', 'cost', 'county'])

# thingSorted.to_csv('./sortaDups.csv')

# thing.groupby([thing.index.year]).row_id.count().plot()

# thing.groupby([thing.index.year, thing.index.month]).row_id.count().plot()

# thing.groupby([thing.index.year, thing.index.month]).cost_per_watt.median().plot()

# thing.to_csv('../local/data/thing0108')

# len(dfLive.incentive.value_counts())
