# %% [markdown]
# #### Wouldn't it be nice...
#
# Wouldn't it be nice to consolidate the install_type field because there are 24 unique values, of which many are broken.
#
# I want to edit a particular row, but in order to set a column value, I need a unique id.
# That is a real annoyance because I don't have a unique row indexer.  For this date (the index)
# I have 286 entries...
#
# It seems like there are two choices here:
# 1. wipe out the smallest 12 categories
# 2. figure out how to get at these and make them as right as I can.
#
# There are a few issues.  Option 1 isn't good because it leaves me with categories that still need to be consolidated.
#
# Here's a brainstorm on how to edit the install_type:
# What we need to do is apply a mapping from actual to target for every one of these bad types.  That's actually pretty easy since I have all the values from values_count.  So all I need is the mapping.

# %%
# %load ../pycode/setup.py
# set up
import numpy as np
import pandas as pd
import random
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %matplotlib inline

def ecdf(data):
    '''Compute ECDF for a one-dimensional array of measurements.'''
    n = len(data)
    x = np.sort(data)
    y = np.arange(1, n + 1) / n
    return x, y

def min015099max(series):
    ''' return list of [ min, 1%, median, 99%, max ] series values '''
    vals = list(np.percentile(series, [1.0, 50.0, 99.0]))
    vals.insert(-1, series.max())
    vals.insert(0, series.min())
    return vals

# ss = np.arange(1, 101)
# min_1_50_99_max(ss)             

def mid98(series):
    '''  return middle 98% of series '''
    bounds = series.quantile([0.01, 0.99])
    return(series[(series > bounds.values[0]) & (series < bounds.values[1])])

# ss = np.arange(1, 101)
# min_1_50_99_max(ss)

# %%
# load more concise dataset for exploration
dfLive = pd.read_csv('../local/data/live20171229.csv', index_col='date_installed', 
                     parse_dates=True, dtype={'zipcode' : np.object})

# %%
dfLive.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1002025 entries, 2004-01-01 to 2015-12-31
# Data columns (total 18 columns):
# cost_per_watt    745516 non-null float64
# cost             745629 non-null float64
# size_kw          1002025 non-null float64
# state            1002025 non-null object
# zipcode          1002025 non-null object
# city             788849 non-null object
# county           980790 non-null object
# install_type     966720 non-null object
# new_constr       27098 non-null float64
# tracking         1920 non-null float64
# third_party      306989 non-null float64
# appraised        223431 non-null object
# incentive        788415 non-null object
# utility          783186 non-null object
# tech             580399 non-null object
# model            580399 non-null object
# installer        694390 non-null object
# bipv             5252 non-null float64
# dtypes: float64(7), object(11)
# memory usage: 145.3+ MB

# %%
dfLive.install_type.value_counts()
# Out:
# residential                    898178
# commercial                      35928
# unknown                         19189
# government                       5675
# nonprofit                        4191
# educational                      2363
# agricultural                      343
# customer                          326
# utility                           224
# education                         209
# institutional                      29
# commercial - other                 16
# public                             15
# gov't/np                           11
# agriculture                         5
# residential/sf                      5
# nonresidential                      3
# not stated                          2
# commercial - small business         2
# small business                      2
# municipal                           1
# commerical                          1
# commercial - builders               1
# commercial - agriculture            1
# Name: install_type, dtype: int64

# %%
theInstallTypes = list(dfLive.install_type.value_counts().index)

# %%
theInstallTypes = list(dfLive.install_type.value_counts().index)

# %%
theInstallTypes.sort(); theInstallTypes
# Out:
# ['agricultural',
#  'agriculture',
#  'commercial',
#  'commercial - agriculture',
#  'commercial - builders',
#  'commercial - other',
#  'commercial - small business',
#  'commerical',
#  'customer',
#  'education',
#  'educational',
#  "gov't/np",
#  'government',
#  'institutional',
#  'municipal',
#  'nonprofit',
#  'nonresidential',
#  'not stated',
#  'public',
#  'residential',
#  'residential/sf',
#  'small business',
#  'unknown',
#  'utility']

# %%
len(theInstallTypes)
# Out:
# 24

# %%
dfLive[dfLive.install_type == 'commercial - agriculture']
# Out:
#                 cost_per_watt      cost  size_kw state zipcode city  county  \
# date_installed
# 2009-12-31               8.58  12009.79      1.4    OH   43432  NaN  Ottawa
#
#                             install_type  new_constr  tracking  third_party  \
# date_installed
# 2009-12-31      commercial - agriculture         NaN       NaN          NaN
#
#                appraised incentive utility tech model installer  bipv
# date_installed
# 2009-12-31           NaN       NaN     NaN  NaN   NaN       NaN   NaN

# %%
# watch out
dfLive[dfLive.install_type == 'commercial - agriculture'].index
# Out:
# DatetimeIndex(['2009-12-31'], dtype='datetime64[ns]', name='date_installed', freq=None)

# %%
# I want to set the 'install_type' in the row above.  
# To do it using .loc I need row and column indexes but...
# I don't have a unique id for the row.
dfLive.loc[dfLive[dfLive.install_type == 'commercial - agriculture'].index, :]
# Out:
#                 cost_per_watt        cost      size_kw state zipcode  \
# date_installed
# 2009-12-31           9.042553   510000.00    56.400000    MA   01701
# 2009-12-31           5.787037   700000.00   120.960000    AZ   85215
# 2009-12-31           7.964912    22700.00     2.850000    CA   91335
# 2009-12-31           5.616331   105924.00    18.860000    AZ   85718
# 2009-12-31           9.067576    11969.20     1.320000    CA   95616
# 2009-12-31                NaN         NaN     4.400000    IN   47401
# 2009-12-31           5.748715    58177.00    10.120000    TX   75154
# 2009-12-31           5.857488    48500.00     8.280000    CA   95658
# 2009-12-31           7.223766    25283.18     3.500000    CA   94611
# 2009-12-31                NaN         NaN     1.200000    IN   47408
# 2009-12-31          14.000000    21168.00     1.512000    CA   92562
# 2009-12-31                NaN         NaN     4.600000    HI   96768
# 2009-12-31           7.368715    27116.87     3.680000    CA   93030
# 2009-12-31                NaN         NaN     1.750000    IN   47403
# 2009-12-31                NaN         NaN     2.675000    IN   47403
# 2009-12-31           6.939056     9992.24     1.440000    CA   93030
# 2009-12-31                NaN         NaN     1.200000    IN   47408
# 2009-12-31           8.271429    17370.00     2.100000    CA   94708
# 2009-12-31                NaN         NaN   700.600000    NJ   08817
# 2009-12-31           5.999630    24776.65     4.129696    CA   94306
# 2009-12-31           9.940133  6600000.00   663.975000    AZ   85308
# 2009-12-31                NaN         NaN     0.660000    IN   47401
# 2009-12-31          10.119048  3400000.00   336.000000    AZ   85308
# 2009-12-31                NaN         NaN     3.250000    IN   47401
# 2009-12-31           8.020000    38500.00     4.800000    TN   38351
# 2009-12-31           2.206576     5825.36     2.640000    NM   88007
# 2009-12-31                NaN         NaN     0.020000    IN   47408
# 2009-12-31           5.813162    34007.00     5.850000    CA   91941
# 2009-12-31           6.068896    28038.30     4.620000    AZ   85387
# 2009-12-31                NaN         NaN    11.280000    HI   96790
# ...                       ...         ...          ...   ...     ...
# 2009-12-31           8.700000    17851.00     2.052000    CA   94531
# 2009-12-31           8.699318    17851.00     2.052000    CA   94531
# 2009-12-31                NaN         NaN     9.000000    IN   47611
# 2009-12-31           5.920000    84600.00    14.300000    CA   95928
# 2009-12-31           7.030000    30932.00     4.400000    CA   90027
# 2009-12-31           8.004143    26893.92     3.360000    CA   90230
# 2009-12-31           6.182188    19783.00     3.200000    CA   94526
# %%
typeMap = { 'agricultural'                : 'agricultural',
            'agriculture'                 : 'agricultural',
            'commercial'                  : 'commercial',           
            'commerical'                  : 'commercial',
            'customer'                    : 'unknown',
            'education'                   : 'educational',
            'educational'                 : 'educational',
            "gov't/np"                    : 'government',
            'government'                  : 'government',
            'institutional'               : 'nonprofit',
            'municipal'                   : 'government',
            'nonprofit'                   : 'nonprofit',
            'nonresidential'              : 'unknown',
            'not stated'                  : 'unknown',
            'public'                      : 'government',
            'residential'                 : 'residential',
            'residential/sf'              : 'residential',
            'small business'              : 'commercial',
            'unknown'                     : 'unknown',
            'utility'                     : 'utility',
            'commercial - agriculture'    : 'agricultural',
            'commercial - builders'       : 'commercial',
            'commercial - other'          : 'commercial',
            'commercial - small business' : 'commercial'}

# %%
dfLive.install_type.map(typeMap).count()
# Out:
# 966720

# %%
dfLive.install_type.count()
# Out:
# 966720

# %%
dfLive.install_type.size
# Out:
# 1002025

# %%
dfLive.install_type.map(typeMap).size
# Out:
# 1002025

# %%
i_type_clean = dfLive.install_type.map(typeMap)

# %%
dfLive_with_i_type = dfLive.assign(i_type=i_type_clean)

# %%
# Looks like it worked.
dfLive_with_i_type.loc[dfLive_with_i_type.install_type.notnull() & 
                       (dfLive_with_i_type.install_type != dfLive_with_i_type.i_type)]
# Out:
#                 cost_per_watt        cost   size_kw state zipcode city  \
# date_installed
# 2004-01-07               9.36   117980.00    12.600    NJ   07934  NaN
# 2004-01-08                NaN        0.00     2.220    WI   53570  NaN
# 2004-01-15               9.21    36490.00     3.960    FL   34604  NaN
# 2004-01-15              10.03    16852.00     1.680    FL   32608  NaN
# 2004-01-15              10.03    16852.00     1.680    FL   32605  NaN
# 2004-01-17                NaN        0.00     2.800    WI   54234  NaN
# 2004-01-30               1.62    90000.00    55.500    OH   45309  NaN
# 2004-01-30               7.75    37180.00     4.800    FL   32609  NaN
# 2004-02-15               2.72     3095.86     1.140    WI   54406  NaN
# 2004-02-16              14.02    14017.90     1.000    WI   54814  NaN
# 2004-02-18               8.95     2229.79     0.249    WI   54909  NaN
# 2004-03-04               6.69    16720.30     2.500    WI   53704  NaN
# 2004-03-19               7.86    31106.00     3.960    FL   32401  NaN
# 2004-03-20              10.04    26826.00     2.672    WI   53517  NaN
# 2004-04-04               9.67    21762.45     2.250    WI   54481  NaN
# 2004-04-05              10.00    13000.00     1.300    WA   98801  NaN
# 2004-04-21              10.00    13000.00     1.300    WA   98801  NaN
# 2004-04-23              10.50    42000.00     4.000    FL   33556  NaN
# 2004-05-01               6.79    13589.50     2.000    WI   54104  NaN
# 2004-05-06               7.61     5632.00     0.740    WI   54022  NaN
# 2004-05-19               8.59    21705.99     2.528    WI   54406  NaN
# 2004-05-24               6.77    34214.00     5.056    WI   53925  NaN
# 2004-06-02               3.55     3936.74     1.110    WI   53704  NaN
# 2004-06-03               9.42    15539.00     1.650    WI   54209  NaN
# 2004-06-14               5.91    10400.00     1.760    WI   53705  NaN
# 2004-06-28               5.81    17883.97     3.080    WI   53095  NaN
# 2004-06-28               9.49     5693.00     0.600    FL   32168  NaN
# 2004-06-28               5.56    22257.00     4.000    FL   32128  NaN
# 2004-06-29               8.75    18270.00     2.088    WI   54471  NaN
# 2004-07-02              10.00    13000.00     1.300    WA   98801  NaN
# ...                       ...         ...       ...   ...     ...  ...
# 2009-12-01               8.40  1044250.00   124.250    NJ   08234  NaN
# 2009-12-01                NaN         NaN    98.000    TN   37660  NaN
# 2009-12-03              10.02   947000.00    94.500    NJ   08234  NaN
# 2009-12-03               6.25  1652467.00   264.250    NJ   08234  NaN
# 2009-12-07              10.50    53570.00     5.100    TX   76708  NaN
# 2009-12-11                NaN         NaN   248.400    NJ   08302  NaN
# 2009-12-15              16.99    17840.00     1.050    TX   75009  NaN
# 2009-12-15              16.99    17840.00     1.050    TX   76107  NaN
# 2009-12-15              16.99    17840.00     1.050    TX   75116  NaN
# 2009-12-17              16.51    54152.00     3.280    TX   75217  NaN
# 2009-12-20                NaN         NaN   107.100    OR   97006  NaN
# 2009-12-24               8.33    46000.00     5.520    TN   37391  NaN
# 2009-12-31               8.58    12009.79     1.400    OH   43432  NaN
# 2010-01-01              10.23     3889.00     0.380    AL   35550  NaN
# 2010-01-12               4.46   300750.00    67.500    TX   78539  NaN
# 2010-01-12               4.74   179250.00    37.800    TX   78539  NaN
# 2010-01-22                NaN         NaN  2000.000    CO   80523  NaN
# 2010-01-27               7.52    45901.81     6.105    MN   55906  NaN
# 2010-02-01               5.90    81243.00    13.770    NJ   07430  NaN
# 2010-02-05               6.63  1237167.00   186.624    NJ   08234  NaN
# 2010-02-08               5.65    86445.00    15.300    TX   75275  NaN
# 2010-02-15               7.50     7500.00     1.000    AL   36265  NaN
# 2010-02-15               8.51   122500.00    14.400    OH   43560  NaN
# 2010-02-15               7.50     7500.00     1.000    AL   36750  NaN
# 2010-02-16               8.01   325000.00    40.565    NJ   07452  NaN
# 2010-02-22                NaN         NaN   219.960    NJ   08062  NaN
# 2010-03-15               9.94    28035.00     2.820    WI   53144  NaN
# 2010-04-09              10.00    30000.00     3.000    IL   62703  NaN
# 2010-04-29               7.50    52523.00     7.000    IL   62650  NaN
# 2010-05-04               7.94    85750.00    10.800    IN   47713  NaN
#
#                       county              install_type  new_constr  tracking  \
# date_installed
# 2004-01-07          Somerset                 education         NaN       NaN
# 2004-01-08             Green                  customer         NaN       NaN
# 2004-01-15          Hernando                 education         NaN       NaN
# 2004-01-15           Alachua                 education         NaN       NaN
# 2004-01-15           Alachua                 education         NaN       NaN
# 2004-01-17              Door                  customer         NaN       NaN
# 2004-01-30        Montgomery                commerical         NaN       NaN
# 2004-01-30           Alachua                 education         NaN       NaN
# 2004-02-15           Portage                  customer         NaN       NaN
# 2004-02-16          Bayfield                  customer         NaN       NaN
# 2004-02-18           Portage                  customer         NaN       NaN
# 2004-03-04              Dane                  customer         NaN       NaN
# 2004-03-19               Bay                 education         NaN       NaN
# 2004-03-20              Dane                  customer         NaN       NaN
# 2004-04-04           Portage                  customer         NaN       NaN
# 2004-04-05            Chelan                 education         NaN       NaN
# 2004-04-21            Chelan                 education         NaN       NaN
# 2004-04-23      Hillsborough                 education         NaN       NaN
# 2004-05-01         Marinette                  customer         NaN       NaN
# 2004-05-06            Pierce                  customer         NaN       NaN
# 2004-05-19           Portage                  customer         NaN       NaN
# 2004-05-24          Columbia                  customer         NaN       NaN
# 2004-06-02              Dane                  customer         NaN       NaN
# 2004-06-03              Door                  customer         NaN       NaN
# 2004-06-14              Dane                  customer         NaN       NaN
# 2004-06-28        Washington                  customer         NaN       NaN
# 2004-06-28           Volusia                 education         NaN       NaN
# 2004-06-28           Volusia                 education         NaN       NaN
# 2004-06-29          Marathon                  customer         NaN       NaN
# 2004-07-02            Chelan                 education         NaN       NaN
# ...                      ...                       ...         ...       ...
# 2009-12-01          Atlantic                 education         NaN       NaN
# 2009-12-01          Sullivan                 education         NaN       NaN
# 2009-12-03          Atlantic                 education         NaN       NaN
# 2009-12-03          Atlantic                 education         NaN       NaN
# 2009-12-07          McLennan                  gov't/np         NaN       NaN
# 2009-12-11        Cumberland                 education         NaN       NaN
# 2009-12-15            Collin                  gov't/np         NaN       NaN
# 2009-12-15           Tarrant                  gov't/np         NaN       NaN
# 2009-12-15            Dallas                  gov't/np         NaN       NaN
# 2009-12-17            Dallas                  gov't/np         NaN       NaN
# 2009-12-20        Washington                 education         NaN       NaN
# 2009-12-24              Polk               agriculture         NaN       NaN
# 2009-12-31            Ottawa  commercial - agriculture         NaN       NaN
# 2010-01-01            Walker                 education         NaN       NaN
# 2010-01-12           Hidalgo                  gov't/np         NaN       NaN
# 2010-01-12           Hidalgo                  gov't/np         NaN       NaN
# 2010-01-22           Larimer                 education         NaN       NaN
# 2010-01-27           Olmsted                 education         NaN       NaN
# 2010-02-01            Bergen                 education         NaN       NaN
# 2010-02-05          Atlantic                 education         NaN       NaN
# 2010-02-08            Dallas                  gov't/np         NaN       NaN
# 2010-02-15           Calhoun                 education         NaN       NaN
# 2010-02-15             Lucas             institutional         NaN       NaN
# 2010-02-15           Chilton                 education         NaN       NaN
# 2010-02-16            Bergen                 education         NaN       NaN
# 2010-02-22        Gloucester                 education         NaN       NaN
# 2010-03-15           Kenosha                 education         NaN       NaN
# 2010-04-09          Sangamon                 education         NaN       NaN
# 2010-04-29            Morgan               agriculture         NaN       NaN
# 2010-05-04       Vanderburgh                 education         NaN       NaN
#
#                 third_party appraised incentive utility tech model installer  \
# date_installed
# 2004-01-07              NaN       NaN       NaN     NaN  NaN   NaN       NaN
# 2004-01-08              NaN       NaN       NaN     NaN  NaN   NaN       NaN
# 2004-01-15              NaN       NaN       NaN     NaN  NaN   NaN       NaN
# 2004-01-15              NaN       NaN       NaN     NaN  NaN   NaN       NaN
# 2004-01-15              NaN       NaN       NaN     NaN  NaN   NaN       NaN
# 2004-01-17              NaN       NaN       NaN     NaN  NaN   NaN       NaN
# 2004-01-30              NaN       NaN       NaN     NaN  NaN   NaN       NaN
# 2004-01-30              NaN       NaN       NaN     NaN  NaN   NaN       NaN
# 2004-02-15              NaN       NaN       NaN     NaN  NaN   NaN       NaN
# 2004-02-16              NaN       NaN       NaN     NaN  NaN   NaN       NaN
# 2004-02-18              NaN       NaN       NaN     NaN  NaN   NaN       NaN
# 2004-03-04              NaN       NaN       NaN     NaN  NaN   NaN       NaN
# 2004-03-19              NaN       NaN       NaN     NaN  NaN   NaN       NaN
# 2004-03-20              NaN       NaN       NaN     NaN  NaN   NaN       NaN
# 2004-04-04              NaN       NaN       NaN     NaN  NaN   NaN       NaN
# 2004-04-05              NaN       NaN       NaN     NaN  NaN   NaN       NaN
# 2004-04-21              NaN       NaN       NaN     NaN  NaN   NaN       NaN
# 2004-04-23              NaN       NaN       NaN     NaN  NaN   NaN       NaN
# 2004-05-01              NaN       NaN       NaN     NaN  NaN   NaN       NaN
# 2004-05-06              NaN       NaN       NaN     NaN  NaN   NaN       NaN
# 2004-05-19              NaN       NaN       NaN     NaN  NaN   NaN       NaN
# 2004-05-24              NaN       NaN       NaN     NaN  NaN   NaN       NaN
# 2004-06-02              NaN       NaN       NaN     NaN  NaN   NaN       NaN
# 2004-06-03              NaN       NaN       NaN     NaN  NaN   NaN       NaN
# 2004-06-14              NaN       NaN       NaN     NaN  NaN   NaN       NaN
# 2004-06-28              NaN       NaN       NaN     NaN  NaN   NaN       NaN
# 2004-06-28              NaN       NaN       NaN     NaN  NaN   NaN       NaN
# 2004-06-28              NaN       NaN       NaN     NaN  NaN   NaN       NaN
# 2004-06-29              NaN       NaN       NaN     NaN  NaN   NaN       NaN
# 2004-07-02              NaN       NaN       NaN     NaN  NaN   NaN       NaN
# ...                     ...       ...       ...     ...  ...   ...       ...
# 2009-12-01              NaN       NaN       NaN     NaN  NaN   NaN       NaN
# 2009-12-01              NaN       NaN       NaN     NaN  NaN   NaN       NaN
# 2009-12-03              NaN       NaN       NaN     NaN  NaN   NaN       NaN
# 2009-12-03              NaN       NaN       NaN     NaN  NaN   NaN       NaN
# 2009-12-07              NaN       NaN       NaN     NaN  NaN   NaN       NaN
# 2009-12-11              NaN       NaN       NaN     NaN  NaN   NaN       NaN
# 2009-12-15              NaN       NaN       NaN     NaN  NaN   NaN       NaN
# 2009-12-15              NaN       NaN       NaN     NaN  NaN   NaN       NaN
# 2009-12-15              NaN       NaN       NaN     NaN  NaN   NaN       NaN
# 2009-12-17              NaN       NaN       NaN     NaN  NaN   NaN       NaN
# 2009-12-20              NaN       NaN       NaN     NaN  NaN   NaN       NaN
# 2009-12-24              NaN       NaN       NaN     NaN  NaN   NaN       NaN
# 2009-12-31              NaN       NaN       NaN     NaN  NaN   NaN       NaN
# 2010-01-01              NaN       NaN       NaN     NaN  NaN   NaN       NaN
# 2010-01-12              NaN       NaN       NaN     NaN  NaN   NaN       NaN
# 2010-01-12              NaN       NaN       NaN     NaN  NaN   NaN       NaN
# 2010-01-22              NaN       NaN       NaN     NaN  NaN   NaN       NaN
# 2010-01-27              NaN       NaN       NaN     NaN  NaN   NaN       NaN
# 2010-02-01              NaN       NaN       NaN     NaN  NaN   NaN       NaN
# 2010-02-05              NaN       NaN       NaN     NaN  NaN   NaN       NaN
# 2010-02-08              NaN       NaN       NaN     NaN  NaN   NaN       NaN
# 2010-02-15              NaN       NaN       NaN     NaN  NaN   NaN       NaN
# 2010-02-15              NaN       NaN       NaN     NaN  NaN   NaN       NaN
# 2010-02-15              NaN       NaN       NaN     NaN  NaN   NaN       NaN
# 2010-02-16              NaN       NaN       NaN     NaN  NaN   NaN       NaN
# 2010-02-22              NaN       NaN       NaN     NaN  NaN   NaN       NaN
# 2010-03-15              NaN       NaN       NaN     NaN  NaN   NaN       NaN
# 2010-04-09              NaN       NaN       NaN     NaN  NaN   NaN       NaN
# 2010-04-29              NaN       NaN       NaN     NaN  NaN   NaN       NaN
# 2010-05-04              NaN       NaN       NaN     NaN  NaN   NaN       NaN
#
#                 bipv        i_type
# date_installed
# 2004-01-07       NaN   educational
# 2004-01-08       NaN       unknown
# 2004-01-15       NaN   educational
# 2004-01-15       NaN   educational
# 2004-01-15       NaN   educational
# 2004-01-17       NaN       unknown
# 2004-01-30       NaN    commercial
# 2004-01-30       NaN   educational
# 2004-02-15       NaN       unknown
# 2004-02-16       NaN       unknown
# 2004-02-18       NaN       unknown
# 2004-03-04       NaN       unknown
# 2004-03-19       NaN   educational
# 2004-03-20       NaN       unknown
# 2004-04-04       NaN       unknown
# 2004-04-05       NaN   educational
# 2004-04-21       NaN   educational
# 2004-04-23       NaN   educational
# 2004-05-01       NaN       unknown
# 2004-05-06       NaN       unknown
# 2004-05-19       NaN       unknown
# 2004-05-24       NaN       unknown
# 2004-06-02       NaN       unknown
# 2004-06-03       NaN       unknown
# 2004-06-14       NaN       unknown
# 2004-06-28       NaN       unknown
# 2004-06-28       NaN   educational
# 2004-06-28       NaN   educational
# 2004-06-29       NaN       unknown
# 2004-07-02       NaN   educational
# ...              ...           ...
# 2009-12-01       NaN   educational
# 2009-12-01       NaN   educational
# 2009-12-03       NaN   educational
# 2009-12-03       NaN   educational
# 2009-12-07       NaN    government
# 2009-12-11       NaN   educational
# 2009-12-15       NaN    government
# 2009-12-15       NaN    government
# 2009-12-15       NaN    government
# 2009-12-17       NaN    government
# 2009-12-20       NaN   educational
# 2009-12-24       NaN  agricultural
# 2009-12-31       NaN  agricultural
# 2010-01-01       NaN   educational
# 2010-01-12       NaN    government
# 2010-01-12       NaN    government
# 2010-01-22       NaN   educational
# 2010-01-27       NaN   educational
# 2010-02-01       NaN   educational
# 2010-02-05       NaN   educational
# 2010-02-08       NaN    government
# 2010-02-15       NaN   educational
# 2010-02-15       NaN     nonprofit
# 2010-02-15       NaN   educational
# 2010-02-16       NaN   educational
# 2010-02-22       NaN   educational
# 2010-03-15       NaN   educational
# 2010-04-09       NaN   educational
# 2010-04-29       NaN  agricultural
# 2010-05-04       NaN   educational
#
# [629 rows x 19 columns]

# %%
# so if I add up all the value_counts of install_types I mapped, I should get 629...
dfLive_with_i_type.loc[dfLive_with_i_type.install_type.notnull() & 
                       (dfLive_with_i_type.install_type != dfLive_with_i_type.i_type)].count()
# Out:
# cost_per_watt    544
# cost             549
# size_kw          629
# state            629
# zipcode          629
# city               0
# county           629
# install_type     629
# new_constr         0
# tracking           0
# third_party        0
# appraised          0
# incentive          0
# utility            0
# tech               0
# model              0
# installer          0
# bipv               0
# i_type           629
# dtype: int64

# %%
mappedTypes = [key for key in typeMap if key != typeMap[key]]; mappedTypes
# Out:
# ['agriculture',
#  'commerical',
#  'customer',
#  'education',
#  "gov't/np",
#  'institutional',
#  'municipal',
#  'nonresidential',
#  'not stated',
#  'public',
#  'residential/sf',
#  'small business',
#  'commercial - agriculture',
#  'commercial - builders',
#  'commercial - other',
#  'commercial - small business']

# %%
# very nice
dfLive.install_type.value_counts()[mappedTypes].sum()
# Out:
# 629

# %%
# sweet
dfLive_with_i_type.i_type.value_counts()
# Out:
# residential     898183
# commercial       35950
# unknown          19520
# government        5702
# nonprofit         4220
# educational       2572
# agricultural       349
# utility            224
# Name: i_type, dtype: int64

# %%
dfLive.columns
# Out:
# Index(['cost_per_watt', 'cost', 'size_kw', 'state', 'zipcode', 'city',
#        'county', 'install_type', 'new_constr', 'tracking', 'third_party',
#        'appraised', 'incentive', 'utility', 'tech', 'model', 'installer',
#        'bipv'],
#       dtype='object')

# %%
dfLive.install_type.value_counts()
# Out:
# residential                    898178
# commercial                      35928
# unknown                         19189
# government                       5675
# nonprofit                        4191
# educational                      2363
# agricultural                      343
# customer                          326
# utility                           224
# education                         209
# institutional                      29
# commercial - other                 16
# public                             15
# gov't/np                           11
# agriculture                         5
# residential/sf                      5
# nonresidential                      3
# not stated                          2
# commercial - small business         2
# small business                      2
# municipal                           1
# commerical                          1
# commercial - builders               1
# commercial - agriculture            1
# Name: install_type, dtype: int64

# %%
dfLive_with_i_type.install_type.value_counts()
# Out:
# residential                    898178
# commercial                      35928
# unknown                         19189
# government                       5675
# nonprofit                        4191
# educational                      2363
# agricultural                      343
# customer                          326
# utility                           224
# education                         209
# institutional                      29
# commercial - other                 16
# public                             15
# gov't/np                           11
# agriculture                         5
# residential/sf                      5
# nonresidential                      3
# not stated                          2
# commercial - small business         2
# small business                      2
# municipal                           1
# commerical                          1
# commercial - builders               1
# commercial - agriculture            1
# Name: install_type, dtype: int64

# %%
dfLive_with_i_type.columns
# Out:
# Index(['cost_per_watt', 'cost', 'size_kw', 'state', 'zipcode', 'city',
#        'county', 'install_type', 'new_constr', 'tracking', 'third_party',
#        'appraised', 'incentive', 'utility', 'tech', 'model', 'installer',
#        'bipv', 'i_type'],
#       dtype='object')

# %%
dfLive_with_i_type.i_type.value_counts()
# Out:
# residential     898183
# commercial       35950
# unknown          19520
# government        5702
# nonprofit         4220
# educational       2572
# agricultural       349
# utility            224
# Name: i_type, dtype: int64

# %%
# drop install_type??
# reassign dfLive??
# for sure save the data...
dfLive = dfLive_with_i_type.drop('install_type', axis='columns')

# %%
dfLive.to_csv('../local/data/20180101.csv')

# %%
dfLive.zipcode[:24]
# Out:
# date_installed
# 2004-01-01    37397
# 2004-01-01    55407
# 2004-01-01    95616
# 2004-01-01    92504
# 2004-01-01    83115
# 2004-01-01    94707
# 2004-01-01    59101
# 2004-01-01    95819
# 2004-01-01    91711
# 2004-01-01    92833
# 2004-01-01    96725
# 2004-01-01    90804
# 2004-01-01    91024
# 2004-01-01    93453
# 2004-01-01    37771
# 2004-01-01    91711
# 2004-01-01    92399
# 2004-01-01    92646
# 2004-01-01    59711
# 2004-01-01    93722
# 2004-01-01    59718
# 2004-01-01    95037
# 2004-01-01    93465
# 2004-01-01    95452
# Name: zipcode, dtype: object

# %%
dfLive.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1002025 entries, 2004-01-01 to 2015-12-31
# Data columns (total 18 columns):
# cost_per_watt    745516 non-null float64
# cost             745629 non-null float64
# size_kw          1002025 non-null float64
# state            1002025 non-null object
# zipcode          1002025 non-null object
# city             788849 non-null object
# county           980790 non-null object
# new_constr       27098 non-null float64
# tracking         1920 non-null float64
# third_party      306989 non-null float64
# appraised        223431 non-null object
# incentive        788415 non-null object
# utility          783186 non-null object
# tech             580399 non-null object
# model            580399 non-null object
# installer        694390 non-null object
# bipv             5252 non-null float64
# i_type           966720 non-null object
# dtypes: float64(7), object(11)
# memory usage: 165.3+ MB
